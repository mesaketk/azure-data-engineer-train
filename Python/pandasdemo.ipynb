# %%
import pyodbc 

cnxn = pyodbc.connect("Driver={/usr/local/lib/libmsodbcsql.18.dylib};Server=sakettestserver.database.windows.net;UID=saket;PWD=Mansa@0902;Database=demo;")

# %%
import pandas as pd

# %%
salesorderdetails = pd.read_sql_query('select * from [SalesLT].[SalesOrderDetail]',cnxn)
salesorderdetails
# Out:
# /var/folders/m9/xdn0jwwj5tvd4_rps56n7tpr0000gn/T/ipykernel_87988/1213158454.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   salesorderdetails = pd.read_sql_query('select * from [SalesLT].[SalesOrderDetail]',cnxn)
#      SalesOrderID  SalesOrderDetailID  OrderQty  ProductID  UnitPrice  \
# 0           71774              110562         1        836    356.898
# 1           71774              110563         1        822    356.898
# 2           71776              110567         1        907     63.900
# 3           71780              110616         4        905    218.454
# 4           71780              110617         2        983    461.694
# ..            ...                 ...       ...        ...        ...
# 537         71938              113312         3        715     29.994
# 538         71938              113313         1        881     32.394
# 539         71938              113314         2        875      5.394
# 540         71938              113315         3        800    672.294
# 541         71946              113406         1        916     31.584
#
#      UnitPriceDiscount  LineTotal                               rowguid  \
# 0                  0.0    356.898  E3A1994C-7A68-4CE8-96A3-77FDD3BBD730
# 1                  0.0    356.898  5C77F557-FDB6-43BA-90B9-9A7AEC55CA32
# 2                  0.0     63.900  6DBFE398-D15D-425E-AA58-88178FE360E5
# 3                  0.0    873.816  377246C9-4483-48ED-A5B9-E56F005364E0
# 4                  0.0    923.388  43A54BCD-536D-4A1B-8E69-24D083507A14
# ..                 ...        ...                                   ...
# 537                0.0     89.982  64FBAAAB-9400-4664-ADD7-97115B75B27B
# 538                0.0     32.394  67D4E5D4-9629-49A6-A6E0-9E1C4CDEE3DE
# 539                0.0     10.788  352D06E9-8456-4966-9C73-3F227B023962
# 540                0.0   2016.882  78F73142-E566-453F-A2B9-88A0FCAF4552
# 541                0.0     31.584  B571CEE0-A90A-4E76-9796-379B55352A28
#
#     ModifiedDate
# 0     2008-06-01
# 1     2008-06-01
# 2     2008-06-01
# 3     2008-06-01
# 4     2008-06-01
# ..           ...
# 537   2008-06-01
# 538   2008-06-01
# 539   2008-06-01
# 540   2008-06-01
# 541   2008-06-01
#
# [542 rows x 9 columns]

# %%
salesorderdetails.sort_values(by=['ProductID','OrderQty'],ascending=False,inplace=True)

# %%
salesorderdetails.drop_duplicates(subset=['ProductID'],inplace=True)

# %%
salesorderdetails=salesorderdetails[['ProductID','OrderQty']]

# %%
product = pd.read_sql_query('select * from [SalesLT].[Product]',cnxn)
# Out:
# /var/folders/m9/xdn0jwwj5tvd4_rps56n7tpr0000gn/T/ipykernel_87988/2395885921.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   product = pd.read_sql_query('select * from [SalesLT].[Product]',cnxn)

# %%
product
# Out:
#      ProductID                       Name ProductNumber  Color  StandardCost  \
# 0          680  HL Road Frame - Black, 58    FR-R92B-58  Black     1059.3100
# 1          706    HL Road Frame - Red, 58    FR-R92R-58    Red     1059.3100
# 2          707      Sport-100 Helmet, Red     HL-U509-R    Red       13.0863
# 3          708    Sport-100 Helmet, Black       HL-U509  Black       13.0863
# 4          709     Mountain Bike Socks, M     SO-B909-M  White        3.3963
# ..         ...                        ...           ...    ...           ...
# 290        995          ML Bottom Bracket       BB-8107   None       44.9506
# 291        996          HL Bottom Bracket       BB-9108   None       53.9416
# 292        997         Road-750 Black, 44    BK-R19B-44  Black      343.6496
# 293        998         Road-750 Black, 48    BK-R19B-48  Black      343.6496
# 294        999         Road-750 Black, 52    BK-R19B-52  Black      343.6496
#
#      ListPrice  Size   Weight  ProductCategoryID  ProductModelID  \
# 0      1431.50    58  1016.04                 18               6
# 1      1431.50    58  1016.04                 18               6
# 2        34.99  None      NaN                 35              33
# 3        34.99  None      NaN                 35              33
# 4         9.50     M      NaN                 27              18
# ..         ...   ...      ...                ...             ...
# 290     101.24  None   168.00                  9              96
# 291     121.49  None   170.00                  9              97
# 292     539.99    44  8967.47                  6              31
# 293     539.99    48  9130.77                  6              31
# 294     539.99    52  9262.31                  6              31
#
#     SellStartDate SellEndDate DiscontinuedDate  \
# 0      2002-06-01         NaT             None
# 1      2002-06-01         NaT             None
# 2      2005-07-01         NaT             None
# 3      2005-07-01         NaT             None
# 4      2005-07-01  2006-06-30             None
# ..            ...         ...              ...
# 290    2007-07-01         NaT             None
# 291    2007-07-01         NaT             None
# 292    2007-07-01         NaT             None
# 293    2007-07-01         NaT             None
# 294    2007-07-01         NaT             None
#
#                                         ThumbNailPhoto  \
# 0    b'GIF89aP\x001\x00\xf7\x00\x00\x00\x00\x00\x80...
# 1    b'GIF89aP\x001\x00\xf7\x00\x00\x00\x00\x00\x80...
# 2    b'GIF89aP\x001\x00\xf7\x00\x00\x00\x00\x00\x80...
# 3    b'GIF89aP\x001\x00\xf7\x00\x00\x00\x00\x00\x80...
# 4    b'GIF89aP\x001\x00\xf7\x00\x00\x00\x00\x00\x80...
# ..                                                 ...
# 290  b'GIF89aP\x001\x00\xf7\x00\x00\x00\x00\x00\x80...
# 291  b'GIF89aP\x001\x00\xf7\x00\x00\x00\x00\x00\x80...
# 292  b'GIF89aP\x001\x00\xf7\x00\x00\xcd\xc9\xca\xc3...
# 293  b'GIF89aP\x001\x00\xf7\x00\x00\xcd\xc9\xca\xc3...
# 294  b'GIF89aP\x001\x00\xf7\x00\x00\xcd\xc9\xca\xc3...
#
#            ThumbnailPhotoFileName                               rowguid  \
# 0    no_image_available_small.gif  43DD68D6-14A4-461F-9069-55309D90EA7E
# 1    no_image_available_small.gif  9540FF17-2712-4C90-A3D1-8CE5568B2462
# 2    no_image_available_small.gif  2E1EF41A-C08A-4FF6-8ADA-BDE58B64A712
# 3    no_image_available_small.gif  A25A44FB-C2DE-4268-958F-110B8D7621E2
# 4    no_image_available_small.gif  18F95F47-1540-4E02-8F1F-CC1BCB6828D0
# ..                            ...                                   ...
# 290  no_image_available_small.gif  71AB847F-D091-42D6-B735-7B0C2D82FC84
# 291  no_image_available_small.gif  230C47C5-08B2-4CE3-B706-69C0BDD62965
# 292      roadster_black_small.gif  44CE4802-409F-43AB-9B27-CA53421805BE
# 293      roadster_black_small.gif  3DE9A212-1D49-40B6-B10A-F564D981DBDE
# 294      roadster_black_small.gif  AE638923-2B67-4679-B90E-ABBAB17DCA31
#
#                ModifiedDate
# 0   2008-03-11 10:01:36.827
# 1   2008-03-11 10:01:36.827
# 2   2008-03-11 10:01:36.827
# 3   2008-03-11 10:01:36.827
# 4   2008-03-11 10:01:36.827
# ..                      ...
# 290 2008-03-11 10:01:36.827
# 291 2008-03-11 10:01:36.827
# 292 2008-03-11 10:01:36.827
# 293 2008-03-11 10:01:36.827
# 294 2008-03-11 10:01:36.827
#
# [295 rows x 17 columns]

# %%
final_table = pd.merge(salesorderdetails,product,on='ProductID',how='inner')

# %%
final_table
# Out:
#      ProductID  OrderQty                        Name ProductNumber  Color  \
# 0          999         5          Road-750 Black, 52    BK-R19B-52  Black
# 1          998         7          Road-750 Black, 48    BK-R19B-48  Black
# 2          997         3          Road-750 Black, 44    BK-R19B-44  Black
# 3          996         4           HL Bottom Bracket       BB-9108   None
# 4          994         3           LL Bottom Bracket       BB-7421   None
# ..         ...       ...                         ...           ...    ...
# 137        714         9  Long-Sleeve Logo Jersey, M     LJ-0192-M  Multi
# 138        712        11                AWC Logo Cap       CA-1098  Multi
# 139        711        15      Sport-100 Helmet, Blue     HL-U509-B   Blue
# 140        708        12     Sport-100 Helmet, Black       HL-U509  Black
# 141        707        10       Sport-100 Helmet, Red     HL-U509-R    Red
#
#      StandardCost  ListPrice  Size   Weight  ProductCategoryID  \
# 0        343.6496     539.99    52  9262.31                  6
# 1        343.6496     539.99    48  9130.77                  6
# 2        343.6496     539.99    44  8967.47                  6
# 3         53.9416     121.49  None   170.00                  9
# 4         23.9716      53.99  None   223.00                  9
# ..            ...        ...   ...      ...                ...
# 137       38.4923      49.99     M      NaN                 25
# 138        6.9223       8.99  None      NaN                 23
# 139       13.0863      34.99  None      NaN                 35
# 140       13.0863      34.99  None      NaN                 35
# 141       13.0863      34.99  None      NaN                 35
#
#      ProductModelID SellStartDate SellEndDate DiscontinuedDate  \
# 0                31    2007-07-01         NaT             None
# 1                31    2007-07-01         NaT             None
# 2                31    2007-07-01         NaT             None
# 3                97    2007-07-01         NaT             None
# 4                95    2007-07-01         NaT             None
# ..              ...           ...         ...              ...
# 137              11    2005-07-01         NaT             None
# 138               2    2005-07-01         NaT             None
# 139              33    2005-07-01         NaT             None
# 140              33    2005-07-01         NaT             None
# 141              33    2005-07-01         NaT             None
#
#                                         ThumbNailPhoto  \
# 0    b'GIF89aP\x001\x00\xf7\x00\x00\xcd\xc9\xca\xc3...
# 1    b'GIF89aP\x001\x00\xf7\x00\x00\xcd\xc9\xca\xc3...
# 2    b'GIF89aP\x001\x00\xf7\x00\x00\xcd\xc9\xca\xc3...
# 3    b'GIF89aP\x001\x00\xf7\x00\x00\x00\x00\x00\x80...
# 4    b'GIF89aP\x001\x00\xf7\x00\x00\x00\x00\x00\x80...
# ..                                                 ...
# 137  b'GIF89aP\x002\x00\xf7\x00\x00\x14%g\xfc\xfc\x...
# 138  b'GIF89aP\x001\x00\xf7\x00\x00\x00\x00\x00\x80...
# 139  b'GIF89aP\x001\x00\xf7\x00\x00\x00\x00\x00\x80...
# 140  b'GIF89aP\x001\x00\xf7\x00\x00\x00\x00\x00\x80...
# 141  b'GIF89aP\x001\x00\xf7\x00\x00\x00\x00\x00\x80...
#
#            ThumbnailPhotoFileName                               rowguid  \
# 0        roadster_black_small.gif  AE638923-2B67-4679-B90E-ABBAB17DCA31
# 1        roadster_black_small.gif  3DE9A212-1D49-40B6-B10A-F564D981DBDE
# 2        roadster_black_small.gif  44CE4802-409F-43AB-9B27-CA53421805BE
# 3    no_image_available_small.gif  230C47C5-08B2-4CE3-B706-69C0BDD62965
# 4    no_image_available_small.gif  FA3C65CD-0A22-47E3-BDF6-53F1DC138C43
# ..                            ...                                   ...
# 137     awc_jersey_male_small.gif  6A290063-A0CF-432A-8110-2EA0FDA14308
# 138  no_image_available_small.gif  B9EDE243-A6F4-4629-B1D4-FFE1AEDC6DE7
# 139  no_image_available_small.gif  FD7C0858-4179-48C2-865B-ABD5DFC7BC1D
# 140  no_image_available_small.gif  A25A44FB-C2DE-4268-958F-110B8D7621E2
# 141  no_image_available_small.gif  2E1EF41A-C08A-4FF6-8ADA-BDE58B64A712
#
#                ModifiedDate
# 0   2008-03-11 10:01:36.827
# 1   2008-03-11 10:01:36.827
# 2   2008-03-11 10:01:36.827
# 3   2008-03-11 10:01:36.827
# 4   2008-03-11 10:01:36.827
# ..                      ...
# 137 2008-03-11 10:01:36.827
# 138 2008-03-11 10:01:36.827
# 139 2008-03-11 10:01:36.827
# 140 2008-03-11 10:01:36.827
# 141 2008-03-11 10:01:36.827
#
# [142 rows x 18 columns]

# %%
final_table = final_table[['ProductID','OrderQty','Name']]

# %%
final_table.to_csv('~/Downloads/Products.csv')

# %%
from sqlalchemy import create_engine
import urllib
import pyodbc
import pandas as pd

quoted = urllib.parse.quote_plus("Driver={/usr/local/lib/libmsodbcsql.18.dylib};Server=sakettestserver.database.windows.net;UID=saket;PWD=Mansa@0902;Database=demo;")

engine = create_engine('mssql+pyodbc:///?odbc_connect={}'.format(quoted))

final_table.to_sql('ProductOrders', schema='SalesLT', con = engine)
# Out:
# -1

# %%
for index,row in final_table.iterrows():
    if row['Name'] == 'Road-750 Black, 52':
        row['Name'] = 'Siva'
        print(row)
# Out:
# ProductID     999
# OrderQty        5
# Name         Siva
# Name: 0, dtype: object

# %%
final_table.describe()
# Out:
#         ProductID    OrderQty
# count  142.000000  142.000000
# mean   889.190141    5.760563
# std     85.724442    4.108337
# min    707.000000    1.000000
# 25%    815.250000    3.000000
# 50%    906.000000    5.000000
# 75%    962.750000    7.000000
# max    999.000000   25.000000

# %%
final_table.columns
# Out:
# Index(['ProductID', 'OrderQty', 'Name'], dtype='object')

# %%
final_table['ProductID'].astype('string')
# Out:
# 0      999
# 1      998
# 2      997
# 3      996
# 4      994
#       ...
# 137    714
# 138    712
# 139    711
# 140    708
# 141    707
# Name: ProductID, Length: 142, dtype: string

# %%
final_table['ProductID']
# Out:
# 0      999
# 1      998
# 2      997
# 3      996
# 4      994
#       ...
# 137    714
# 138    712
# 139    711
# 140    708
# 141    707
# Name: ProductID, Length: 142, dtype: int64
